# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager
import time
import re

# %%
# Inicializa navegador
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

url = 'https://techguide.sh/pt-BR/path/java/'
driver.get(url)
time.sleep(3)  # Aguarda carregamento

# Títulos dos botões da página
expressoes_desejadas = []
pattern = re.compile(r'\*\*(.*?)\*\*')
with open('../nomes_botoes.txt', 'r') as arquivo:
    linhas = arquivo.readlines()
    for linha in linhas:
        
        match = pattern.search(linha)
        if match:
            expressoes_desejadas.append(match.group(1))

# Extrai HTML da página
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# Localiza botões com <p> contendo as expressões

botoes_relevantes = []

for button in soup.find_all('button'):
    p_tag = button.find('p')
    if p_tag:
        texto = p_tag.get_text(strip=True)
        if any(expr.lower() in texto.lower() for expr in expressoes_desejadas):
            classes = button.get('class')
            if classes:
                botoes_relevantes.append({'texto': texto, 'classe': classes})  # Salva lista completa

# %%
# Lista para armazenar links
todos_os_links = []

# Processa cada botão relevante
for botao in botoes_relevantes:
    try:
        condicoes_xpath = ' and '.join([f'contains(@class, "{c}")' for c in botao['classe']])
        xpath_botao = f'//button[{condicoes_xpath}]'

        elemento_botao = driver.find_element(By.XPATH, xpath_botao)
        driver.execute_script("arguments[0].scrollIntoView({block: 'center'});", elemento_botao)
        time.sleep(0.5)
        elemento_botao.click()
        time.sleep(1)

        # Pega divs visíveis e captura links
        divs = driver.find_elements(By.TAG_NAME, 'div')
        divs_visiveis = [d for d in divs if d.is_displayed()]

        for div in divs_visiveis:
            links = div.find_elements(By.TAG_NAME, 'a')
            for link in links:
                href = link.get_attribute('href')
                text = link.text
                category = botao['texto']
            
                if href and href not in todos_os_links:
                    temp_dict = {}
                    temp_dict['categoria'] = category
                    temp_dict['texto'] = text
                    temp_dict['link'] = href 
                    todos_os_links.append(temp_dict)
                

    # Fecha a div
        close_icon = driver.find_element(By.XPATH, '//*[@id="__next"]/div/div/div[2]/div[1]/div[2]')
        close_icon.click()
        time.sleep(1)

    except Exception as e:
        print(f'Erro no botão "{botao["texto"]}": {e}')
        continue

print(f'Total de links capturados: {len(todos_os_links)}')
print(todos_os_links)

driver.quit()
# Out:
# Total de links capturados: 2766
# [{'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://techguide.sh/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://techguide.sh/pt-BR/path/java/#7days-of-code'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://techguide.sh/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://techguide.sh/en-US/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://techguide.sh/es/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://techguide.sh/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://techguide.sh/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://techguide.sh/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://7daysofcode.io/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://alura.com.br/dev-em-t'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://github.com/alura/techguide'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://github.com/alura/techguide'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://techguide.sh/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://www.alura.com.br/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://www.cursospm3.com.br/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://www.fiap.com.br/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://github.com/alura/techguide'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://youtube.com/aluracursosonline'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://www.facebook.com/AluraCursosOnline/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://twitter.com/aluraonline'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://www.instagram.com/aluraonline/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://play.google.com/store/apps/details?id=br.com.alura.mobi'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://apps.apple.com/br/app/alura-cursos-online/id1225776635'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': '', 'link': 'https://www.tiktok.com/@aluraonline'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': 'SITEGitHub Documentação', 'link': 'https://docs.github.com/pt'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': 'SITEGitHub Pages Documentação', 'link': 'https://docs.github.com/pt/pages/getting-started-with-github-pages/about-github-pages'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': 'SITEGit School - Visualizing Git', 'link': 'https://git-school.github.io/visualizing-git/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': 'SITEDangit, Git!?!', 'link': 'https://dangitgit.com/'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': 'YOUTUBERafaella Ballerini: O que é Git e GitHub? - definição e conceitos importantes 1/2', 'link': 'https://www.youtube.com/watch?v=DqTITcMq68k'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': 'YOUTUBERafaella Ballerini: Como usar Git e GitHub na prática! - desde o primeiro commit até o pull request! 2/2', 'link': 'https://www.youtube.com/watch?v=UBAX-13g8OM'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': 'YOUTUBEMario Souto - Dev Soutinho: Git: Entendendo de vez como funciona do melhor e mais visual jeito possível', 'link': 'https://www.youtube.com/watch?v=4-tfJ-ZyA0Q'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': 'YOUTUBEMario Souto - Dev Soutinho: Como colocar seu projeto no ar DE GRAÇA via GitHub! | Hospedagem com GitHub Pages', 'link': 'https://www.youtube.com/watch?v=BU-w2_Aae54'}, {'categoria': 'Git e GitHub - Fundamentos', 'texto': 'YOUTUBECodandoTV(Rods) - 5 coisas que você precisa saber so ...

# %%
links_filtrado = [link for link in todos_os_links if link['texto'] != '']
print(len(todos_os_links))
print(len(links_filtrado))
# Out:
# 2766
# 2042

# %%
from functions import get_source, create_soup

relacao_tipos = ['ARTIGO', 'CURSO', 'DESAFIO', 'LIVRO', 'PODCAST', 'SITE', 'YOUTUBE']



# Exportando csv

import pandas as pd
df = pd.DataFrame(links_filtrado)


# iterando para criar coluna tipo e limpar coluna texto
for index, linha in df.iterrows():
    if 'ARTIGO' in linha['texto']:
        df.at[index, 'texto'] = df.at[index, 'texto'].replace('ARTIGO', '')
        df.at[index, 'tipo'] = 'ARTIGO'
    if 'CURSO' in linha['texto']:
        df.at[index, 'texto'] = df.at[index, 'texto'].replace('CURSO', '')
        df.at[index, 'tipo'] = 'CURSO'
        
        soup = create_soup(linha['link'])
        paragrafos = soup.find_all('p')
        padrao = re.compile(r'\d+h')
        for p in paragrafos:
            match = padrao.search(p.text)
            if match:
                df.at[index, 'carga_horaria'] = match
        
    if 'DESAFIO' in linha['texto']:
        df.at[index, 'texto'] = df.at[index, 'texto'].replace('DESAFIO', '')
        df.at[index, 'tipo'] = 'DESAFIO'
    if 'LIVRO' in linha['texto']:
        df.at[index, 'texto'] = df.at[index, 'texto'].replace('LIVRO', '')
        df.at[index, 'tipo'] = 'LIVRO'
    if 'PODCAST' in linha['texto']:
        df.at[index, 'texto'] = df.at[index, 'texto'].replace('PODCAST', '')
        df.at[index, 'tipo'] = 'PODCAST'
    if 'YOUTUBE' in linha['texto']:
        df.at[index, 'texto'] = df.at[index, 'texto'].replace('YOUTUBE', '')
        df.at[index, 'tipo'] = 'YOUTUBE'
    if 'SITE' in linha['texto']:
        df.at[index, 'texto'] = df.at[index, 'texto'].replace('SITE', '')
        df.at[index, 'tipo'] = 'SITE'



# Continuar criando colunas de tipo (SITE, ARTIGO, CURSO etc) e carga horaria dos cursos



df.to_csv('links_filtrado.csv')

# %%
for index, linha in df.iterrows():
    if linha['tipo'] == 'CURSO':
        print(linha['texto'])
        #soup = create_soup(linha['link'])
        #paragrafos = soup.find_all('p')
        #print(p.text)
# Out:
# Curso Git e GitHub: compartilhando e colaborando em projetos
# Curso Git e GitHub: dominando controle de versão de código
# Curso Git e GitHub: compartilhando e colaborando em projetos
# Curso Git e GitHub: dominando controle de versão de código
# Curso Git e GitHub: compartilhando e colaborando em projetos
# Curso Git e GitHub: dominando controle de versão de código
# Curso Git e GitHub: compartilhando e colaborando em projetos
# Curso Git e GitHub: dominando controle de versão de código
# Curso Git e GitHub: compartilhando e colaborando em projetos
# Curso Git e GitHub: dominando controle de versão de código
# Curso Git e GitHub: compartilhando e colaborando em projetos
# Curso Git e GitHub: dominando controle de versão de código
# Curso HTTP: Entendendo a web por baixo dos panos
# Curso HTTP: Entendendo a web por baixo dos panos
# Curso HTTP: Entendendo a web por baixo dos panos
# Curso HTTP: Entendendo a web por baixo dos panos
# Curso HTTP: Entendendo a web por baixo dos panos
# Curso HTTP: Entendendo a web por baixo dos panos
# Curso MySQL e JSON: persistindo JSON de maneira eficiente
# Curso MySQL e JSON: persistindo JSON de maneira eficiente
# Curso MySQL e JSON: persistindo JSON de maneira eficiente
# Curso MySQL e JSON: persistindo JSON de maneira eficiente
# Curso MySQL e JSON: persistindo JSON de maneira eficiente
# Curso MySQL e JSON: persistindo JSON de maneira eficiente
# Curso Windows Prompt: Trabalhando na linha de comando
# Curso Terminal: aprenda comandos para executar tarefas
# Curso Windows Prompt: Trabalhando na linha de comando
# Curso Terminal: aprenda comandos para executar tarefas
# Curso Windows Prompt: Trabalhando na linha de comando
# Curso Terminal: aprenda comandos para executar tarefas
# Curso Windows Prompt: Trabalhando na linha de comando
# Curso Terminal: aprenda comandos para executar tarefas
# Curso Windows Prompt: Trabalhando na linha de comando
# Curso Terminal: aprenda comandos para executar tarefas
# Curso Windows Prompt: Trabalhando na linha de comando
# Curso Terminal: aprenda comandos para executar tarefas
# Formação Começando em Cloud Computing
# Formação Amazon Web Services
# Formação Google Certified Associate Cloud Engineer
# Formação Certificação AWS Certified Cloud Practitioner
# Formação Containers com AWS ECS e EKS
# Formação Google Cloud Platform
# Formação Certificação Google Certified Associate Cloud Engineer
# Formação Azure
# Formação Certificação AZ-900: Microsoft Azure Fundamentals
# Formação Começando em Cloud Computing
# Formação Amazon Web Services
# Formação Google Certified Associate Cloud Engineer
# Formação Certificação AWS Certified Cloud Practitioner
# Formação Containers com AWS ECS e EKS
# Formação Google Cloud Platform
# Formação Certificação Google Certified Associate Cloud Engineer
# Formação Azure
# Formação Certificação AZ-900: Microsoft Azure Fundamentals
# Formação Começando em Cloud Computing
# Formação Amazon Web Services
# Formação Google Certified Associate Cloud Engineer
# Formação Certificação AWS Certified Cloud Practitioner
# Formação Containers com AWS ECS e EKS
# Formação Google Cloud Platform
# Formação Certificação Google Certified Associate Cloud Engineer
# Formação Azure
# Formação Certificação AZ-900: Microsoft Azure Fundamentals
# Formação Começando em Cloud Computing
# Formação Amazon Web Services
# Formação Google Certified Associate Cloud Engineer
# Formação Certificação AWS Certified Cloud Practitioner
# Formação Containers com AWS ECS e EKS
# Formação Google Cloud Platform
# Formação Certificação Google Certified Associate Cloud Engineer
# Formação Azure
# Formação Certificação AZ-900: Microsoft Azure Fundamentals
# Formação Começando em Cloud Computing
# Formação Amazon Web Services
# Formação Google Certified Associate Cloud Engineer
# Formação Certificação AWS Certified Cloud Practitioner
# Formação Containers com AWS ECS e EKS
# Formação Google Cloud Platform
# Formação Certificação Google Certified Associate Cloud Engineer
# Formação Azure
# Formação Certificação AZ-900: Microsoft Azure Fundamentals
# Formação Começando em Cloud Computing
# Formação Amazon Web Services
# Formação Google Certified Associate Cloud Engineer
# Formação Certificação AWS Certified Cloud Practitioner
# Formação Containers com AWS ECS e EKS
# Formação Google Cloud Platform
# Formação Certificação Google Certified Associate Cloud Engineer
# Formação Azure
# Formação Certificação AZ-900: Microsoft Azure Fundamentals
# Formação Conhecendo SQL
# Curso SQL com MySQL: manipule e consulte dados
# Formação SQL com MySQL Server da Oracle
# Microsoft SQL Server 2022: conhecendo SQL
# Curso de PostgreSQL
# SQL com Oracle Database: manipule e consulte dados
# Formação Conhecendo SQL
# Curso SQL com MySQL: manipule e consulte dados
# Formação SQL com MySQL Server da Oracle
# Microsoft SQL Server 2022: conhecendo SQL
# Curso de PostgreSQL
# SQL com Oracle Database: manipule e consulte dados
# Formação Conhecendo SQL
# Curso SQL com MySQL: manipule e consulte dados
# Formação SQL com MySQL Server da Oracle
# Microsoft SQL Server 2022: conhecendo SQL
# Curso de PostgreSQL
# SQL com Oracle Database: manipule e consulte dados
# Formação Conhecendo SQL
# Curso SQL com MySQL: manipule e consulte dados
# Formação SQL com MySQL Server da Oracle
# Microsoft SQL Server 2022: conhecendo SQL
# Curso de PostgreSQL
# SQL com Oracle Database: manipule e consulte dados
# Formação Conhecendo SQL
# Curso SQL com MySQL: manipule e consulte dados
# Formação SQL com MySQL Server da Oracle
# Microsoft SQL Server 2022: conhecendo SQL
# Curso de PostgreSQL
# SQL com Oracle Database: manipule e consulte dados
# Formação Conhecendo SQL
# Curso SQL com MySQL: manipule e consulte dados
# Formação SQL com MySQL Server da Oracle
# Microsoft SQL Server 2022: conhecendo SQL
# Curso de PostgreSQL
# SQL com Oracle Database: manipule e consulte dados
# Formação A partir do zero: iniciante em programação
# Formação A partir do zero: iniciante em programação
# Formação A partir do zero: iniciante em programação
# Formação A partir do zero: iniciante em programação
# Formação A partir do zero: iniciante em programação
# Formação A partir do zero: iniciante em programação
# Formação Java e Orientação a Objetos
# Formação Java e Orientação a Objetos
# Formação Java e Orientação a Objetos
# Formação Java e Orientação a Objetos
# Formação Java e Orientação a Objetos
# Formação Java e Orientação a Objetos
# Formação Java e Orientação a Objetos
# Formação C# e Orientação a Objetos
# Formação Python e orientação a objetos
# Curso Orientação a Objetos com PHP: Classes, métodos e atributos
# Curso JavaScript: programação orientada a objetos
# Formação Java e Orientação a Objetos
# Formação C# e Orientação a Objetos
# Formação Python e orientação a objetos
# Curso Orientação a Objetos com PHP: Classes, métodos e atributos
# Curso JavaScript: programação orientada a objetos
# Formação Java e Orientação a Objetos
# Formação C# e Orientação a Objetos
# Formação Python e orientação a objetos
# Curso Orientação a Objetos com PHP: Classes, métodos e atributos
# Curso JavaScript: programação orientada a objetos
# Formação Java e Orientação a Objetos
# Formação C# e Orientação a Objetos
# Formação Python e orientação a objetos
# Curso Orientação a Objetos com PHP: Classes, métodos e atributos
# Curso JavaScript: programação orientada a objetos
# Formação Java e Orientação a Objetos
# Formação C# e Orientação a Objetos
# Formação Python e orientação a objetos
# Curso Orientação a Objetos com PHP: Classes, métodos e atributos
# Curso JavaScript: programação orientada a objetos
# Formação Java e Orientação a Objetos
# Formação C# e Orientação a Objetos
# Formação Python e orientação a objetos
# Curso Orientação a Objetos com PHP: Classes, métodos e atributos
# Curso JavaScript: programação orientada a objetos
# Curso Java exceções: aprenda a criar, lançar e controlar exceções
# Curso Java exceções: aprenda a criar, lançar e controlar exceções
# Curso Java exceções: aprenda a criar, lançar e controlar exceções
# Curso Java exceções: aprenda a criar, lançar e controlar exceções
# Curso Java exceções: aprenda a criar, lançar e controlar exceções
# Curso Java exceções: aprenda a criar, lançar e controlar exceções
# Curso Java: trabalhando com listas e coleções de dados
# Curso Java: trabalhando com listas e coleções de dados
# Curso Java: trabalhando com listas e coleções de dados
# Curso Java: trabalhando com listas e coleções de dados
# Curso Java: trabalhando com listas e coleções de dados
# Curso Java: trabalhando com listas e coleções de dados
# Curso Java e refatoração: melhorando códigos com boas práticas
# Curso Boas práticas de programação: automatizando testes com Java
# Curso Selenium: testes automatizados de aceitação em Java
# Curso BDD e Java: Behavior Driven Development com Cucumber
# Curso Java e refatoração: melhorando códigos com boas práticas
# Curso Boas práticas de programação: automatizando testes com Java
# Curso Selenium: testes automatizados de aceitação em Java
# Curso BDD e Java: Behavior Driven Development com Cucumber
# Curso Java e refatoração: melhorando códigos com boas práticas
# Curso Boas práticas de programação: automatizando testes com Java
# Curso Selenium: testes automatizados de aceitação em Java
# Curso BDD e Java: Behavior Driven Development com Cucumber
# Curso Java e refatoração: melhorando códigos com boas práticas
# Curso Boas práticas de programação: automatizando testes com Java
# Curso Selenium: testes automatizados de aceitação em Java
# Curso BDD e Java: Behavior Driven Development com Cucumber
# Curso Java e refatoração: melhorando códigos com boas práticas
# Curso Boas práticas de programação: automatizando testes com Java
# Curso Selenium: testes automatizados de aceitação em Java
# Curso BDD e Java: Behavior Driven Development com Cucumber
# Curso Java e refatoração: melhorando códigos com boas práticas
# Curso Boas práticas de programação: automatizando testes com Java
# Curso Selenium: testes automatizados de aceitação em Java
# Curso BDD e Java: Behavior Driven Development com Cucumber
# Curso Java: trabalhando com listas e coleções de dados
# Curso Java: trabalhando com listas e coleções de dados
# Curso Java: trabalhando com listas e coleções de dados
# Curso Java: trabalhando com listas e coleções de dados
# Curso Java: trabalhando com listas e coleções de dados
# Curso Java: trabalhando com listas e coleções de dados
# Formação Java e Microsserviços com Spring e RabbitMQ
# Formação Java Web: crie aplicações usando Spring Boot
# Formação Java e Microsserviços com Spring e RabbitMQ
# Formação Java Web: crie aplicações usando Spring Boot
# Formação Java e Microsserviços com Spring e RabbitMQ
# Formação Java Web: crie aplicações usando Spring Boot
# Formação Java e Microsserviços com Spring e RabbitMQ
# Formação Java Web: crie aplicações usando Spring Boot
# Formação Java e Microsserviços com Spring e RabbitMQ
# Formação Java Web: crie aplicações usando Spring Boot
# Formação Java e Microsserviços com Spring e RabbitMQ
# Formação Java Web: crie aplicações usando Spring Boot
# Formação Java e Spring Boot
# Formação Java Web: crie aplicações usando Spring Boot
# Formação Java e Spring Boot
# Formação Java Web: crie aplicações usando Spring Boot
# Formação Java e Spring Boot
# Formação Java Web: crie aplicações usando Spring Boot
# Formação Java e Spring Boot
# Formação Java Web: crie aplicações usando Spring Boot
# Formação Java e Spring Boot
# Formação Java Web: crie aplicações usando Spring Boot
# Formação Java e Spring Boot
# Formação Java Web: crie aplicações usando Spring Boot
# Curso Maven: gerencie dependências e faça o build de aplicações Java
# Curso Maven: gerencie dependências e faça o build de aplicações Java
# Curso Maven: gerencie dependências e faça o build de aplicações Java
# Curso Maven: gerencie dependências e faça o build de aplicações Java
# Curso Maven: gerencie dependências e faça o build de aplicações Java
# Curso Maven: gerencie dependências e faça o build de aplicações Java
# Curso Java e JDBC: trabalhando com um banco de dados
# Curso Java e JPA: consultas avançadas, performance e modelos complexos
# Curso Persistência com JPA: Hibernate
# Curso Java e JDBC: trabalhando com um banco de dados
# Curso Java e JPA: consultas avançadas, performance e modelos complexos
# Curso Persistência com JPA: Hibernate
# Curso Java e JDBC: trabalhando com um banco de dados
# Curso Java e JPA: consultas avançadas, performance e modelos complexos
# Curso Persistência com JPA: Hibernate
# Curso Java e JDBC: trabalhando com um banco de dados
# Curso Java e JPA: consultas avançadas, performance e modelos complexos
# Curso Persistência com JPA: Hibernate
# Curso Java e JDBC: trabalhando com um banco de dados
# Curso Java e JPA: consultas avançadas, performance e modelos complexos
# Curso Persistência com JPA: Hibernate
# Curso Java e JDBC: trabalhando com um banco de dados
# Curso Java e JPA: consultas avançadas, performance e modelos complexos
# Curso Persistência com JPA: Hibernate
# Curso Microsserviços: padrões de projeto
# Curso Microsserviços: explorando os conceitos
# Curso Microsserviços na prática: entendendo a tomada de decisões
# Curso Microsserviços: padrões de projeto
# Curso Microsserviços: explorando os conceitos
# Curso Microsserviços na prática: entendendo a tomada de decisões
# Curso Microsserviços: padrões de projeto
# Curso Microsserviços: explorando os conceitos
# Curso Microsserviços na prática: entendendo a tomada de decisões
# Curso Microsserviços: padrões de projeto
# Curso Microsserviços: explorando os conceitos
# Curso Microsserviços na prática: entendendo a tomada de decisões
# Curso Microsserviços: padrões de projeto
# Curso Microsserviços: explorando os conceitos
# Curso Microsserviços na prática: entendendo a tomada de decisões
# Curso Microsserviços: padrões de projeto
# Curso Microsserviços: explorando os conceitos
# Curso Microsserviços na prática: entendendo a tomada de decisões
# Curso Java threads: aprenda a criar, gerenciar e aplicar com o Spring
# Curso Java threads: aprenda a criar, gerenciar e aplicar com o Spring
# Curso Java threads: aprenda a criar, gerenciar e aplicar com o Spring
# Curso Java threads: aprenda a criar, gerenciar e aplicar com o Spring
# Curso Java threads: aprenda a criar, gerenciar e aplicar com o Spring
# Curso Java threads: aprenda a criar, gerenciar e aplicar com o Spring
# Formação Orquestração de containers com Kubernetes
# Curso Docker: criando e gerenciando containers
# Curso Kubernetes: Pods, Services e ConfigMaps
# Curso Kubernetes: Deployments, Volumes e Escalabilidade
# Curso Google Kubernetes Engine
# Curso Kubernetes na Digital Ocean: gerenciando aplicações conteinerizadas
# Curso Amazon EKS: gerenciando aplicações conteinerizadas com Kubernetes
# Curso Azure: gerencie Kubernetes com AKS e ACR
# Formação Orquestração de containers com Kubernetes
# Curso Docker: criando e gerenciando containers
# Curso Kubernetes: Pods, Services e ConfigMaps
# Curso Kubernetes: Deployments, Volumes e Escalabilidade
# Curso Google Kubernetes Engine
# Curso Kubernetes na Digital Ocean: gerenciando aplicações conteinerizadas
# Curso Amazon EKS: gerenciando aplicações conteinerizadas com Kubernetes
# Curso Azure: gerencie Kubernetes com AKS e ACR
# Formação Orquestração de containers com Kubernetes
# Curso Docker: criando e gerenciando containers
# Curso Kubernetes: Pods, Services e ConfigMaps
# Curso Kubernetes: Deployments, Volumes e Escalabilidade
# Curso Google Kubernetes Engine
# Curso Kubernetes na Digital Ocean: gerenciando aplicações conteinerizadas
# Curso Amazon EKS: gerenciando aplicações conteinerizadas com Kubernetes
# Curso Azure: gerencie Kubernetes com AKS e ACR
# Formação Orquestração de containers com Kubernetes
# Curso Docker: criando e gerenciando containers
# Curso Kubernetes: Pods, Services e ConfigMaps
# Curso Kubernetes: Deployments, Volumes e Escalabilidade
# Curso Google Kubernetes Engine
# Curso Kubernetes na Digital Ocean: gerenciando aplicações conteinerizadas
# Curso Amazon EKS: gerenciando aplicações conteinerizadas com Kubernetes
# Curso Azure: gerencie Kubernetes com AKS e ACR
# Formação Orquestração de containers com Kubernetes
# Curso Docker: criando e gerenciando containers
# Curso Kubernetes: Pods, Services e ConfigMaps
# Curso Kubernetes: Deployments, Volumes e Escalabilidade
# Curso Google Kubernetes Engine
# Curso Kubernetes na Digital Ocean: gerenciando aplicações conteinerizadas
# Curso Amazon EKS: gerenciando aplicações conteinerizadas com Kubernetes
# Curso Azure: gerencie Kubernetes com AKS e ACR
# Formação Orquestração de containers com Kubernetes
# Curso Docker: criando e gerenciando containers
# Curso Kubernetes: Pods, Services e ConfigMaps
# Curso Kubernetes: Deployments, Volumes e Escalabilidade
# Curso Google Kubernetes Engine
# Curso Kubernetes na Digital Ocean: gerenciando aplicações conteinerizadas
# Curso Amazon EKS: gerenciando aplicações conteinerizadas com Kubernetes
# Curso Azure: gerencie Kubernetes com AKS e ACR
# Formação Apache Kafka
# Formação Apache Kafka
# Formação Apache Kafka
# Formação Apache Kafka
# Formação Apache Kafka
# Formação Apache Kafka
# Curso C#: aplique princípios SOLID
# Curso Boas práticas de programação: melhore o código de uma API Java
# Curso SOLID com PHP: princípios da programação orientada a objetos
# Curso iOS: escrevendo código de qualidade com SOLID em Swift
# SOLID com TypeScript: aplicando boas práticas em orientação a objetos
# Formação Boas práticas em C#
# Formação Boas práticas em PHP
# Formação Boas práticas em Java
# Curso C#: aplique princípios SOLID
# Curso Boas práticas de programação: melhore o código de uma API Java
# Curso SOLID com PHP: princípios da programação orientada a objetos
# Curso iOS: escrevendo código de qualidade com SOLID em Swift
# SOLID com TypeScript: aplicando boas práticas em orientação a objetos
# Formação Boas práticas em C#
# Formação Boas práticas em PHP
# Formação Boas práticas em Java
# Curso C#: aplique princípios SOLID
# Curso Boas práticas de programação: melhore o código de uma API Java
# Curso SOLID com PHP: princípios da programação orientada a objetos
# Curso iOS: escrevendo código de qualidade com SOLID em Swift
# SOLID com TypeScript: aplicando boas práticas em orientação a objetos
# Formação Boas práticas em C#
# Formação Boas práticas em PHP
# Formação Boas práticas em Java
# Curso C#: aplique princípios SOLID
# Curso Boas práticas de programação: melhore o código de uma API Java
# Curso SOLID com PHP: princípios da programação orientada a objetos
# Curso iOS: escrevendo código de qualidade com SOLID em Swift
# SOLID com TypeScript: aplicando boas práticas em orientação a objetos
# Formação Boas práticas em C#
# Formação Boas práticas em PHP
# Formação Boas práticas em Java
# Curso C#: aplique princípios SOLID
# Curso Boas práticas de programação: melhore o código de uma API Java
# Curso SOLID com PHP: princípios da programação orientada a objetos
# Curso iOS: escrevendo código de qualidade com SOLID em Swift
# SOLID com TypeScript: aplicando boas práticas em orientação a objetos
# Formação Boas práticas em C#
# Formação Boas práticas em PHP
# Formação Boas práticas em Java
# Curso C#: aplique princípios SOLID
# Curso Boas práticas de programação: melhore o código de uma API Java
# Curso SOLID com PHP: princípios da programação orientada a objetos
# Curso iOS: escrevendo código de qualidade com SOLID em Swift
# SOLID com TypeScript: aplicando boas práticas em orientação a objetos
# Formação Boas práticas em C#
# Formação Boas práticas em PHP
# Formação Boas práticas em Java
# Curso Java e Clean Architecture: descomplicando arquitetura de software
# Curso PHP e Clean Architecture: descomplicando arquitetura de software
# Curso Java e Clean Architecture: descomplicando arquitetura de software
# Curso PHP e Clean Architecture: descomplicando arquitetura de software
# Curso Java e Clean Architecture: descomplicando arquitetura de software
# Curso PHP e Clean Architecture: descomplicando arquitetura de software
# Curso Java e Clean Architecture: descomplicando arquitetura de software
# Curso PHP e Clean Architecture: descomplicando arquitetura de software
# Curso Java e Clean Architecture: descomplicando arquitetura de software
# Curso PHP e Clean Architecture: descomplicando arquitetura de software
# Curso Java e Clean Architecture: descomplicando arquitetura de software
# Curso PHP e Clean Architecture: descomplicando arquitetura de software
# Curso Design Patterns em Java I: boas práticas de programação
# Curso Design Patterns C# I: boas práticas de programação
# Curso Design Patterns em PHP: padrões comportamental
# Curso Design Patterns em PHP: padrões estruturais
# Curso Design Patterns em PHP: padrões criacionais
# Curso Design Patterns em Java I: boas práticas de programação
# Curso Design Patterns C# I: boas práticas de programação
# Curso Design Patterns em PHP: padrões comportamental
# Curso Design Patterns em PHP: padrões estruturais
# Curso Design Patterns em PHP: padrões criacionais
# Curso Design Patterns em Java I: boas práticas de programação
# Curso Design Patterns C# I: boas práticas de programação
# Curso Design Patterns em PHP: padrões comportamental
# Curso Design Patterns em PHP: padrões estruturais
# Curso Design Patterns em PHP: padrões criacionais
# Curso Design Patterns em Java I: boas práticas de programação
# Curso Design Patterns C# I: boas práticas de programação
# Curso Design Patterns em PHP: padrões comportamental
# Curso Design Patterns em PHP: padrões estruturais
# Curso Design Patterns em PHP: padrões criacionais
# Curso Design Patterns em Java I: boas práticas de programação
# Curso Design Patterns C# I: boas práticas de programação
# Curso Design Patterns em PHP: padrões comportamental
# Curso Design Patterns em PHP: padrões estruturais
# Curso Design Patterns em PHP: padrões criacionais
# Curso Design Patterns em Java I: boas práticas de programação
# Curso Design Patterns C# I: boas práticas de programação
# Curso Design Patterns em PHP: padrões comportamental
# Curso Design Patterns em PHP: padrões estruturais
# Curso Design Patterns em PHP: padrões criacionais
# Curso Java e Domain Driven Design: apresentando os conceitos
# Curso PHP e Domain Driven Design: apresentando os conceitos
# Curso Java e Domain Driven Design: apresentando os conceitos
# Curso PHP e Domain Driven Design: apresentando os conceitos
# Curso Java e Domain Driven Design: apresentando os conceitos
# Curso PHP e Domain Driven Design: apresentando os conceitos
# Curso Java e Domain Driven Design: apresentando os conceitos
# Curso PHP e Domain Driven Design: apresentando os conceitos
# Curso Java e Domain Driven Design: apresentando os conceitos
# Curso PHP e Domain Driven Design: apresentando os conceitos
# Curso Java e Domain Driven Design: apresentando os conceitos
# Curso PHP e Domain Driven Design: apresentando os conceitos

# %%
df
# Out:
#                                               categoria  \
# 0                            Git e GitHub - Fundamentos
# 1                            Git e GitHub - Fundamentos
# 2                            Git e GitHub - Fundamentos
# 3                            Git e GitHub - Fundamentos
# 4                            Git e GitHub - Fundamentos
# ...                                                 ...
# 2037  Conceitos de Design Orientado a Domínio (Domai...
# 2038  Conceitos de Design Orientado a Domínio (Domai...
# 2039  Conceitos de Design Orientado a Domínio (Domai...
# 2040  Conceitos de Design Orientado a Domínio (Domai...
# 2041  Conceitos de Design Orientado a Domínio (Domai...
#
#                                                   texto  \
# 0                                   GitHub Documentação
# 1                             GitHub Pages Documentação
# 2                          Git School - Visualizing Git
# 3                                        Dangit, Git!?!
# 4     Rafaella Ballerini: O que é Git e GitHub? - de...
# ...                                                 ...
# 2037              Domain-Driven Design (DDD) - O que é?
# 2038  Primeiras aulas do curso Java e Domain Driven ...
# 2039  Curso Java e Domain Driven Design: apresentand...
# 2040  Primeiras aulas do curso PHP e Domain Driven D...
# 2041  Curso PHP e Domain Driven Design: apresentando...
#
#                                                    link     tipo  \
# 0                            https://docs.github.com/pt     SITE
# 1     https://docs.github.com/pt/pages/getting-start...     SITE
# 2         https://git-school.github.io/visualizing-git/     SITE
# 3                                https://dangitgit.com/     SITE
# 4           https://www.youtube.com/watch?v=DqTITcMq68k  YOUTUBE
# ...                                                 ...      ...
# 2037  https://cursos.alura.com.br/extra/alura-mais/d...     SITE
# 2038  https://www.alura.com.br/conteudo/java-domain-...     SITE
# 2039  https://www.alura.com.br/curso-online-java-dom...    CURSO
# 2040  https://www.alura.com.br/conteudo/domain-drive...     SITE
# 2041  https://www.alura.com.br/curso-online-domain-d...    CURSO
#
#                                       carga_horaria
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ...                                             ...
# 2037                                            NaN
# 2038                                            NaN
# 2039  <re.Match object; span=(72, 75), match='24h'>
# 2040                                            NaN
# 2041  <re.Match object; span=(72, 75), match='24h'>
#
# [2042 rows x 5 columns]

# %%
df.to_csv('links_filtrado.csv')
